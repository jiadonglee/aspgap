# %%
import sys
sys.path.append("/home/jdli/transpec")
import torch
import numpy as np
import pandas as pd
from transGaia.transgaia import xp2label
from transGaia.inference import *
from tqdm import tqdm

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import matplotlib
from matplotlib import rcParams, rc
import matplotlib.pyplot as plt
from matplotlib import colors

rcParams["savefig.dpi"] = 100
rcParams["figure.dpi"] = 100
rcParams["font.size"] = 14
rcParams['font.family'] = 'sans-serif'
data_dir = "/data/jdli/gaia/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = "/data/jdli/gaia/"
# fname    = data_dir + "APtransXP_0120_4lbs_err_55coef.csv"

# cat = Table.read(os.environ["SDSS_LOCAL_SAS_MIRROR"]+"/dr17/ap17_gdr3_tm_wise_tr.fits")
cat = Table.read(data_dir+"ap17_gdr3_tm_wise_tr.fits")
names = [name for name in cat.colnames if len(cat[name].shape)<=1]
df_raw = cat[names].to_pandas()
print(df_raw.shape, df_raw.columns)
# df = pd.read_csv(fname)
# print(df.shape, df.columns)
# Out:
# (88325, 93) Index(['APOGEE_ID', 'TELESCOPE', 'FIELD', 'ALT_ID', 'RA', 'DEC', 'GLON',
#        'GLAT', 'J', 'J_ERR', 'H', 'H_ERR', 'K', 'K_ERR', 'AK_TARG',
#        'AK_TARG_METHOD', 'AK_WISE', 'SFD_EBV', 'SNR', 'SNREV', 'STARFLAG',
#        'STARFLAGS', 'ANDFLAG', 'ANDFLAGS', 'VHELIO_AVG', 'VSCATTER', 'VERR',
#        'GAIAEDR3_SOURCE_ID', 'GAIAEDR3_PARALLAX', 'GAIAEDR3_PARALLAX_ERROR',
#        'GAIAEDR3_PMRA', 'GAIAEDR3_PMRA_ERROR', 'GAIAEDR3_PMDEC',
#        'GAIAEDR3_PMDEC_ERROR', 'GAIAEDR3_PHOT_G_MEAN_MAG',
#        'GAIAEDR3_PHOT_BP_MEAN_MAG', 'GAIAEDR3_PHOT_RP_MEAN_MAG',
#        'GAIAEDR3_DR2_RADIAL_VELOCITY', 'GAIAEDR3_DR2_RADIAL_VELOCITY_ERROR',
#        'GAIAEDR3_R_MED_GEO', 'GAIAEDR3_R_LO_GEO', 'GAIAEDR3_R_HI_GEO',
#        'GAIAEDR3_R_MED_PHOTOGEO', 'GAIAEDR3_R_LO_PHOTOGEO',
#        'GAIAEDR3_R_HI_PHOTOGEO', 'ASPCAPFLAG', 'ASPCAPFLAGS', 'TEFF',
#        'TEFF_ERR', 'LOGG', 'LOGG_ERR', 'M_H', 'M_H_ERR', 'ALPHA_M',
#        'ALPHA_M_ERR', 'VSINI', 'source_id', 'visibility_periods_used', 'ruwe',
#        'AllWISE', 'RAJ2000', 'DEJ2000', 'eeMaj', 'eeMin', 'eePA', 'W1mag',
#        'W2mag', 'W3mag', 'W4mag', 'Jmag', 'Hmag', 'Kmag', 'e_W1mag', 'e_W2mag',
#        'e_W3mag', 'e_W4mag', 'e_Jmag', 'e_Hmag', 'e_Kmag', 'ID', 'ccf', 'ex',
#        'var', 'qph', 'pmRA', 'e_pmRA', 'pmDE', 'e_pmDE', 'd2M', 'angDist',
#        '2MASS', 'Qfl', 'Rfl'],
#       dtype='object')

# %%
df_raw['tmass_id'] = [df_raw['APOGEE_ID'][i].decode('utf8').strip() for i in range(len(df_raw))]

# %%
data_dir = "/data/jdli/gaia/"

rdf = pd.read_csv(data_dir + "APtransXP_0120_4lbs_err_55coefs.csv")
# rdf = pd.read_csv(data_dir + "APtransXP_1215_4lbs_55coefs.csv")
print(rdf.shape)
# Out:
# (66695, 54)

# %%
rdf = rdf.merge(df_raw[['source_id', 'tmass_id']], on='source_id')
print(rdf.shape)
# Out:
# (66695, 55)

# %%
rdf.columns
# Out:
# Index(['teff_cross', 'logg_cross', 'moh_cross', 'aom_cross', 'e_teff_cross',
#        'e_logg_cross', 'e_moh_cross', 'e_aom_cross', 'source_id',
#        'source_id_y', 'bp_coef', 'e_bp_coef', 'rp_coef', 'e_rp_coef',
#        'GAIAEDR3_SOURCE_ID', 'J', 'J_ERR', 'H', 'H_ERR', 'K', 'K_ERR',
#        'GAIAEDR3_PARALLAX', 'GAIAEDR3_PARALLAX_ERROR',
#        'GAIAEDR3_PHOT_G_MEAN_MAG', 'GAIAEDR3_PHOT_BP_MEAN_MAG',
#        'GAIAEDR3_PHOT_RP_MEAN_MAG', 'TEFF', 'TEFF_ERR', 'LOGG', 'LOGG_ERR',
#        'M_H', 'M_H_ERR', 'ALPHA_M', 'ALPHA_M_ERR', 'W1mag', 'W2mag', 'W3mag',
#        'W4mag', 'Jmag', 'Hmag', 'Kmag', 'e_W1mag', 'e_W2mag', 'qph_w1',
#        'qph_w2', 'Qfl_J', 'Qfl_H', 'Qfl_K', 'snr_bp', 'snr_bp10', 'snr_bp55',
#        'snr_rp', 'snr_rp10', 'snr_rp55', 'tmass_id'],
#       dtype='object')

# %%
from astropy.io import ascii

gctable =  ascii.read("ftp://cdsarc.u-strasbg.fr/ftp/J/A+A/622/A191/table2.dat",
                   readme="ftp://cdsarc.u-strasbg.fr/ftp/J/A+A/622/A191/ReadMe")

df_gcraw = gctable.to_pandas()

print(df_gcraw.shape, df_gcraw.columns)
# Out:
# (885, 48) Index(['---', '2MASS', 'Cluster', 'Evol', 'Teff', 'logg', '[Fe/H]', 'e_[Fe/H]',
#        'l_[C/Fe]', '[C/Fe]', 'e_[C/Fe]', 'o_[C/Fe]', 'l_[N/Fe]', '[N/Fe]',
#        'e_[N/Fe]', 'o_[N/Fe]', 'l_[O/Fe]', '[O/Fe]', 'e_[O/Fe]', 'o_[O/Fe]',
#        'l_[Mg/Fe]', '[Mg/Fe]', 'e_[Mg/Fe]', 'o_[Mg/Fe]', 'l_[Al/Fe]',
#        '[Al/Fe]', 'e_[Al/Fe]', 'o_[Al/Fe]', 'l_[Si/Fe]', '[Si/Fe]',
#        'e_[Si/Fe]', 'o_[Si/Fe]', 'l_[K/Fe]', '[K/Fe]', 'e_[K/Fe]', 'o_[K/Fe]',
#        'l_[Ca/Fe]', '[Ca/Fe]', 'e_[Ca/Fe]', 'o_[Ca/Fe]', 'l_[Ce/Fe]',
#        '[Ce/Fe]', 'e_[Ce/Fe]', 'o_[Ce/Fe]', 'l_[Nd/Fe]', '[Nd/Fe]',
#        'e_[Nd/Fe]', 'o_[Nd/Fe]'],
#       dtype='object')

# %%
df_gcraw = df_gcraw.assign(tmass_id=df_gcraw['---']+df_gcraw['2MASS'])
df_gcraw.head()
# Out:
#   ---             2MASS Cluster Evol  Teff  logg  [Fe/H]  e_[Fe/H] l_[C/Fe]  \
# 0  2M  17162228+4258036     M92  RGB  4978  1.84     NaN       NaN      NaN
# 1  2M  17163577+4256392     M92  RGB  5051  2.03  -2.199     0.254        <
# 2  2M  17163748+4306155     M92  RGB  4389  0.42  -2.130     0.132      NaN
# 3  2M  17164330+4304161     M92  RGB  4949  1.76  -2.191     0.032        <
# 4  2M  17164395+4307318     M92  RGB  4913  1.67  -2.235     0.235        <
#
#    [C/Fe]  ...  o_[Ca/Fe]  l_[Ce/Fe] [Ce/Fe]  e_[Ce/Fe]  o_[Ce/Fe]  l_[Nd/Fe]  \
# 0     NaN  ...          1          <   1.928        NaN          1        NaN
# 1   1.684  ...          1        NaN     NaN        NaN          0        NaN
# 2  -0.364  ...          1        NaN  -0.258      0.058          3        NaN
# 3   1.230  ...          1          <   2.022        NaN          1        NaN
# 4   0.950  ...          1        NaN     NaN        NaN          0        NaN
#
#   [Nd/Fe]  e_[Nd/Fe]  o_[Nd/Fe]            tmass_id
# 0     NaN        NaN          0  2M17162228+4258036
# 1     NaN        NaN          0  2M17163577+4256392
# 2     NaN        NaN          0  2M17163748+4306155
# 3     NaN        NaN          0  2M17164330+4304161
# 4     NaN        NaN          0  2M17164395+4307318
#
# [5 rows x 49 columns]

# %%
df_gc = df_gcraw.merge(rdf, on='tmass_id')
print(df_gc.shape, df_gc.columns)
# Out:
# (66, 103) Index(['---', '2MASS', 'Cluster', 'Evol', 'Teff', 'logg', '[Fe/H]', 'e_[Fe/H]',
#        'l_[C/Fe]', '[C/Fe]',
#        ...
#        'qph_w2', 'Qfl_J', 'Qfl_H', 'Qfl_K', 'snr_bp', 'snr_bp10', 'snr_bp55',
#        'snr_rp', 'snr_rp10', 'snr_rp55'],
#       dtype='object', length=103)

# %%
df_gc_lite = df_gc[['source_id', 'tmass_id', 'Cluster',  
                    'moh_cross', 'aom_cross', 'e_moh_cross', 'e_aom_cross',
                    'M_H', 'ALPHA_M', ]]

df_gc_lite['FE_H'] = df_gc['[Fe/H]']
df_gc_lite['FE_H_ERR'] = df_gc['e_[Fe/H]']
# Out:
# /tmp/ipykernel_31883/2708991297.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gc_lite['FE_H'] = df_gc['[Fe/H]']
# /tmp/ipykernel_31883/2708991297.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gc_lite['FE_H_ERR'] = df_gc['e_[Fe/H]']

# %%
gc_grouped = df_gc.groupby('Cluster')

gc_grouped = gc_grouped.filter(lambda x: len(x) > 3)

# %%
# Initialize the figure
from matplotlib.lines import Line2D
import seaborn as sns

f, ax = plt.subplots(1,1,figsize=(7,4))
sns.despine(left=True)

# Show each observation with a scatterplot
sns.stripplot(
    data=gc_grouped, x="moh_cross", y="Cluster", 
    marker='^',
    dodge=True, alpha=.8, zorder=1, legend=False,
    ax=ax
)

sns.stripplot(
    data=gc_grouped, x="M_H", y="Cluster", marker='o',
    dodge=True, alpha=.4, zorder=1, legend=False
)

sns.stripplot(
    data=gc_grouped, x="[Fe/H]", y="Cluster", marker='s',
    dodge=True, alpha=.4, zorder=1, legend=False
)

legend_elements = [
    Line2D([0], [0], marker='^', color='w', label='Gaia XP', markerfacecolor='#1f77b4', markersize=8),
    Line2D([0], [0], marker='o', color='w', label='APOGEE', markerfacecolor='#ff7f0e', markersize=8),
    Line2D([0], [0], marker='s', color='w', label='Masseron+2019', markerfacecolor='#2ca02c', markersize=8),
]

ax.legend(handles=legend_elements, loc='upper right', fontsize=12)
ax.set_xlim([-2.5, 0.6]);
ax.set_xlabel("[M/H]");
ax.set_ylabel("Globular Cluster ");

# %%
f, ax = plt.subplots(1,1,figsize=(7,4))
sns.despine(left=True)

# Show each observation with a scatterplot
sns.stripplot(
    data=gc_grouped, x="aom_cross", y="Cluster", 
    # hue="species",
    dodge=True, alpha=.5, zorder=1, legend=False,
    ax=ax
)

sns.stripplot(
    data=gc_grouped, x="ALPHA_M", y="Cluster", 
    dodge=True, alpha=.4, zorder=1, legend=False
)


legend_elements = [
    Line2D([0],[0], marker='^', color='w', label='Gaia XP', markerfacecolor='#1f77b4', markersize=8),
    Line2D([0],[0], marker='o', color='w', label='APOGEE', markerfacecolor='#ff7f0e', markersize=8)
]

ax.legend(handles=legend_elements, loc='upper left', fontsize=12)
ax.set_xlim([-0.5, 0.6]);
ax.set_xlabel(r"[$\alpha$/M]");
ax.set_ylabel("Globular Cluster ");

# %%
moh_range = [-2.5, 0.5]
aom_range = [-0.15, 0.45]

cluster_names = gc_grouped['Cluster'].unique()

# aom_moh_diag = plt.imread("../fig/alpha_dia_bkg.png")

fig, axs = plt.subplots(4,2, figsize=(8, 10), sharey=True, sharex=True)

for i, (gn,cluster) in enumerate(gc_grouped.groupby('Cluster')):

    ax1, ax2 = axs[i,:]
    ax1.scatter(cluster['moh_cross'], cluster['aom_cross'],
                s=8, c='tomato', marker='^')
    ax1.set_xlim(moh_range)
    ax1.set_ylim(aom_range)
    ax1.hist2d(rdf['M_H'], rdf['ALPHA_M'], bins=100, alpha=0.3,
           cmap='binary', norm=colors.LogNorm())
    ax1.text(0.1, 0.2, cluster_names[i], 
            transform=ax1.transAxes, zorder=3)
    ax1.text(0.4, 0.9, 'Gaia XP',
            transform=ax1.transAxes, zorder=3)
    ax1.set_xlabel('[M/H]'); ax1.set_ylabel(r'[$\alpha$/M]');
    
    ax2.scatter(cluster['M_H'], cluster['ALPHA_M'], 
                s=8, c='royalblue', marker='o')
    ax2.set_xlim(moh_range)
    ax2.set_ylim(aom_range)
    ax2.hist2d(rdf['M_H'], rdf['ALPHA_M'], bins=100, alpha=0.3,
           cmap='binary', norm=colors.LogNorm())
    ax2.text(0.1, 0.2, cluster_names[i],
            transform=ax2.transAxes, zorder=3)
    ax2.text(0.4, 0.9, 'APOGEE',
            transform=ax2.transAxes, zorder=3)
    ax2.set_xlabel('[M/H]'); 
    # ax2.set_ylabel(r'[$\alpha$/M]');

# plt.tight_layout()
fig.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.99, wspace=0, hspace=0)
# fig.savefig("../fig/gc_valid.pdf")

# %% [markdown]
# # Omega Cen

# %%
from astropy.table import Table
omegacen = Table.read("../docs/data/omegacen.fits").to_pandas()

print(omegacen.shape, omegacen.columns)
# Out:
# (180, 178) Index(['ID_1', 'RAdeg', 'DEdeg', 'Bmag', 'Vmag', 'Imag', 'Ksmag', 'RV', 'e_RV',
#        'ID_2',
#        ...
#        'Hmag', 'Kmag', 'e_Jmag', 'e_Hmag', 'e_Kmag', 'Qfl', 'Rfl', 'X',
#        'MeasureJD', 'angDist_x'],
#       dtype='object', length=178)

# %%
from astroquery.gaia import Gaia
Gaia.login()

#jli06
#zwHD5BFFcbT@HZW
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# User:  jli06
# Password:  ········
# OK
# INFO: Login to gaia data server [astroquery.gaia.core]
# OK

# %%
def chunks(lst, n):
    ""
    "Split an input list into multiple chunks of size =< n"
    ""
    for i in range(0, len(lst), n):
        yield lst[i:i+n]
        
        
dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
ids          = omegacen['Source']
ids_chunks   = list(chunks(ids, dl_threshold))
datalink_all = []


print(f'* Input list contains {len(ids)} source_IDs')
print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')
# Out:
# * Input list contains 180 source_IDs
# * This list is split into 1 chunks of <= 5000 elements each

# %%
retrieval_type = 'XP_CONTINUOUS'          # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS', 'ALL'
data_structure = 'COMBINED'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW'
data_release   = 'Gaia DR3' # Options are: 'Gaia DR3' (default), 'Gaia DR2'
dl_key         = f'{retrieval_type}_{data_structure}.xml'

datalink_all = []

# dl_keys  = [inp for inp in datalink.keys()]
# dl_keys.sort()

ii = 0
for chunk in ids_chunks:
    ii+=1
    print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
    datalink  = Gaia.load_data(ids=chunk,
                               data_release = data_release, 
                               retrieval_type=retrieval_type, format='votable',
                               data_structure=data_structure)
    
    datalink_all.append(datalink)
# Out:
# Downloading Chunk #1; N_files = 180

# %%
from tqdm import tqdm
import joblib

scaler_bp = joblib.load('../docs/models/scaler_bp.gz')
scaler_rp = joblib.load('../docs/models/scaler_rp.gz')

product_list_tb  = [item for sublist in datalink_all for item in sublist[dl_key]]
# product_list_ids = [item.get_field_by_id("source_id") for sublist in datalink_all for item in sublist[dl_key]]
product_list_ids = [sid for sublist in datalink_all for item in sublist[dl_key] for sid in item.array["source_id"].data]


N_COEFF = 55
bp_coef = []
rp_coef = []

i = 0
for kk,tab in tqdm(enumerate(product_list_tb)):
    
    bp_coefficients         = np.array([d.data for d in tab.array["bp_coefficients"]]).reshape(-1, N_COEFF)
    bp_coefficients_errors  = np.array([d.data for d in tab.array["bp_coefficient_errors"]]).reshape(-1, N_COEFF)


    rp_coefficients         = np.array([d.data for d in tab.array["rp_coefficients"]]).reshape(-1, N_COEFF)
    rp_coefficients_errors  = np.array([d.data for d in tab.array["rp_coefficient_errors"]]).reshape(-1, N_COEFF)
    
    bp_coef.append(bp_coefficients)
    rp_coef.append(rp_coefficients)
    
bp_coef = np.vstack(tuple([_ for _ in bp_coef]))
rp_coef = np.vstack(tuple([_ for _ in rp_coef]))

norm_bp_coef = scaler_bp.transform(np.log10(bp_coef+6*1e4))
norm_rp_coef = scaler_rp.transform(np.log10(rp_coef+6*1e4))

print(bp_coef.shape, rp_coef.shape)
print(len(product_list_ids))


xp = {'norm_bp_coef':norm_bp_coef, 'norm_rp_coef':norm_rp_coef, 
         'source_id':product_list_ids}

gcdf_xp = pd.DataFrame(xp)
np.save(data_dir+"GC_Mucciarelli.npy", xp)
# Out:
# 1it [00:00, 385.68it/s]
# (113, 55) (113, 55)
# 113

# %%
gc_input = np.concatenate((np.concatenate(gcdf_xp['norm_bp_coef'].values, axis=0).reshape(-1,55),
                           np.concatenate(gcdf_xp['norm_rp_coef'].values, axis=0).reshape(-1,55),
                      gcdf_xp[['Jmag','Hmag','Kmag']].values/99.), axis=1)
print(gc_input.shape)
# Out:
# (113, 113)

# %%
xp = {'norm_bp_coef':list(norm_bp_coef), 'norm_rp_coef':list(norm_rp_coef), 
         'source_id':product_list_ids}

gcdf_xp = pd.DataFrame(xp)

gcdf_xp = gcdf_xp.merge(omegacen, left_on='source_id', right_on='Source')
print(gcdf_xp.shape, gcdf_xp.columns)
# Out:
# (113, 181) Index(['norm_bp_coef', 'norm_rp_coef', 'source_id', 'ID_1', 'RAdeg', 'DEdeg',
#        'Bmag', 'Vmag', 'Imag', 'Ksmag',
#        ...
#        'Hmag', 'Kmag', 'e_Jmag', 'e_Hmag', 'e_Kmag', 'Qfl', 'Rfl', 'X',
#        'MeasureJD', 'angDist_x'],
#       dtype='object', length=181)

# %%
import sys
sys.path.append("/home/jdli/transpec")

import torch
from transGaia.transgaia import xp2label
from transGaia.data import GXP_5lb

# %%
device = torch.device('cuda:0')

BATCH_SIZE = 512

model = xp2label(
    n_encoder_inputs=113, n_outputs=4,
    channels=128, n_heads=8, n_layers=8).to(device)


model_name = "/data/jdli/gaia/model/1214_4l/sp2_4l_robustnorm_mse_0_ep200.pt"
model.load_state_dict(torch.load(model_name))
# Out:
# <All keys matched successfully>

# %%
with torch.no_grad():

    lbs_raw = model(torch.tensor(gc_input.astype(np.float32)).to(device))

# %%
from transGaia.inference import *


preds = recover_labels(lbs_raw.cpu().numpy())

# %%
plt.scatter(preds[:,0], preds[:,1])

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
ax.scatter(preds[:,2], preds[:,3], 
            s=8, c='royalblue', marker='o')
ax.set_xlim(moh_range)
ax.set_ylim(aom_range)
ax.hist2d(rdf['M_H'], rdf['ALPHA_M'], bins=100, alpha=0.3,
       cmap='binary', norm=colors.LogNorm())
ax.text(0.1, 0.2, r"$\omega$ Cen.",
        transform=ax.transAxes, zorder=3)
ax.text(0.4, 0.9, 'Gaia XP',
        transform=ax.transAxes, zorder=3)
ax.set_xlabel('[M/H]');
plt.tight_layout()
fig.savefig("../fig/omegacen.pdf")

# %% [markdown]
# # Open cluster

# %%
xtfu = pd.read_csv("xtfu22_v2.csv")
print(xtfu.shape, xtfu.columns)
# Out:
# (1434, 213) Index(['RAdeg_1', 'DEdeg_1', 'Teff_1', 'e_Teff', 'logg_1', 'e_logg', 'feh_lm',
#        'e_feh_lm', 'RV_1', 'e_RV_1',
#        ...
#        'teff_err', 'logg_2', 'logg_err', 'feh', 'feh_err', 'rv_2', 'rv_err',
#        'alpha_m', 'alpha_m_err', 'Separation'],
#       dtype='object', length=213)

# %%
dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
ids          = xtfu['Source']
ids_chunks   = list(chunks(ids, dl_threshold))
datalink_all = []


print(f'* Input list contains {len(ids)} source_IDs')
print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')
# Out:
# * Input list contains 7479 source_IDs
# * This list is split into 2 chunks of <= 5000 elements each

# %%
retrieval_type = 'XP_CONTINUOUS'          # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS', 'ALL'
data_structure = 'COMBINED'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW'
data_release   = 'Gaia DR3' # Options are: 'Gaia DR3' (default), 'Gaia DR2'
dl_key         = f'{retrieval_type}_{data_structure}.xml'

datalink_all = []

# dl_keys  = [inp for inp in datalink.keys()]
# dl_keys.sort()

ii = 0
for chunk in ids_chunks:
    ii+=1
    print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
    datalink  = Gaia.load_data(ids=chunk,
                               data_release = data_release, 
                               retrieval_type=retrieval_type, format='votable',
                               data_structure=data_structure)
    
    datalink_all.append(datalink)
# Out:
# Downloading Chunk #1; N_files = 5000
# Downloading Chunk #2; N_files = 2479

# %%
product_list_tb  = [item for sublist in datalink_all for item in sublist[dl_key]]
product_list_ids = [sid for sublist in datalink_all for item in sublist[dl_key] for sid in item.array["source_id"].data]

N_COEFF = 55
bp_coef = []
rp_coef = []

i = 0
for kk,tab in tqdm(enumerate(product_list_tb)):
    
    bp_coefficients         = np.array([d.data for d in tab.array["bp_coefficients"]]).reshape(-1, N_COEFF)
    bp_coefficients_errors  = np.array([d.data for d in tab.array["bp_coefficient_errors"]]).reshape(-1, N_COEFF)

    rp_coefficients         = np.array([d.data for d in tab.array["rp_coefficients"]]).reshape(-1, N_COEFF)
    rp_coefficients_errors  = np.array([d.data for d in tab.array["rp_coefficient_errors"]]).reshape(-1, N_COEFF)
    
    bp_coef.append(bp_coefficients)
    rp_coef.append(rp_coefficients)
    
bp_coef = np.vstack(tuple([_ for _ in bp_coef]))
rp_coef = np.vstack(tuple([_ for _ in rp_coef]))

norm_bp_coef = scaler_bp.transform(np.log10(bp_coef+6*1e4))
norm_rp_coef = scaler_rp.transform(np.log10(rp_coef+6*1e4))

print(bp_coef.shape, rp_coef.shape)
print(len(product_list_ids))


xp = {'norm_bp_coef':norm_bp_coef, 'norm_rp_coef':norm_rp_coef, 'source_id':product_list_ids}

# ocdf_xp = pd.DataFrame(xp)
np.save(data_dir+"OC_xtfu.npy", xp)
# Out:
# 2it [00:00, 41.56it/s]
# (3831, 55) (3831, 55)
# 3831
# /tmp/ipykernel_31883/1584217796.py:23: RuntimeWarning: invalid value encountered in log10
#   norm_bp_coef = scaler_bp.transform(np.log10(bp_coef+6*1e4))

# %%
ocdf_xp = pd.DataFrame({'norm_bp_coef':list(norm_bp_coef), 
                        'norm_rp_coef':list(norm_rp_coef), 
                        'source_id':product_list_ids})
print(ocdf_xp.shape)

ocdf_xp = pd.merge(ocdf_xp, xtfu, left_on='source_id', right_on='Source', how='left')
print(ocdf_xp.shape, ocdf_xp.columns)
# Out:
# (3831, 3)
# (4012, 216) Index(['norm_bp_coef', 'norm_rp_coef', 'source_id', 'RAdeg_1', 'DEdeg_1',
#        'Teff_1', 'e_Teff', 'logg_1', 'e_logg', 'feh_lm',
#        ...
#        'teff_err', 'logg_2', 'logg_err', 'feh', 'feh_err', 'rv_2', 'rv_err',
#        'alpha_m', 'alpha_m_err', 'Separation'],
#       dtype='object', length=216)

# %%
oc_input = np.concatenate((np.concatenate(ocdf_xp['norm_bp_coef'].values, axis=0).reshape(-1,55),
                           np.concatenate(ocdf_xp['norm_rp_coef'].values, axis=0).reshape(-1,55),
                      ocdf_xp[['Jmag','Hmag','Kmag']].values/99.), axis=1)
print(oc_input.shape)
# Out:
# (6988, 113)

# %%
from transGaia.inference import *

model_name = "/data/jdli/gaia/model/1214_4l/sp2_4l_robustnorm_mse_0_ep200.pt"

lbs_oc = infer_4lbs_model(model_name, oc_input, device=device)

# %%
oc_xp_pred = pd.DataFrame(
    lbs_oc['labels'],
    columns=['teff_cross', 'logg_cross', 'moh_cross', 'aom_cross']
)

oc_xp_pred.columns

oc_xp_pred = pd.concat((ocdf_xp, oc_xp_pred), axis=1)

# %%
# oc_xp_pred.head()

oc_xp_pred = oc_xp_pred.drop_duplicates(subset=['source_id'])
print(oc_xp_pred.shape)
# Out:
# (3818, 220)

# %% [markdown]
# # OCCAM

# %%
octable = Table.read(data_dir+"occam_member-DR17.fits")

df_ocraw = octable.to_pandas()
print(df_ocraw.shape, df_ocraw.columns)

df_ocraw = df_ocraw.assign(tmass_id=[i.decode('utf-8') for i in df_ocraw['APOGEE_ID'].values], 
                           Cluster=[i.decode('utf-8') for i in df_ocraw['CLUSTER'].values])

df_ocraw = df_ocraw[df_ocraw['FEH_PROB']>0.8]
df_oc = df_ocraw.merge(rdf, on="tmass_id", )
print(df_oc.columns, )
# Out:
# (26699, 17) Index(['CLUSTER', 'APOGEE_ID', 'LOCATION_ID', 'GLON', 'GLAT', 'VHELIO_AVG',
#        'VSCATTER', 'FE_H', 'FE_H_ERR', 'PMRA', 'PMRA_ERR', 'PMDEC',
#        'PMDEC_ERR', 'RV_PROB', 'FEH_PROB', 'PM_PROB', 'CG_PROB'],
#       dtype='object')
# Index(['CLUSTER', 'APOGEE_ID', 'LOCATION_ID', 'GLON', 'GLAT', 'VHELIO_AVG',
#        'VSCATTER', 'FE_H', 'FE_H_ERR', 'PMRA', 'PMRA_ERR', 'PMDEC',
#        'PMDEC_ERR', 'RV_PROB', 'FEH_PROB', 'PM_PROB', 'CG_PROB', 'tmass_id',
#        'Cluster', 'teff_cross', 'logg_cross', 'moh_cross', 'aom_cross',
#        'e_teff_cross', 'e_logg_cross', 'e_moh_cross', 'e_aom_cross',
#        'source_id', 'source_id_y', 'bp_coef', 'e_bp_coef', 'rp_coef',
#        'e_rp_coef', 'GAIAEDR3_SOURCE_ID', 'J', 'J_ERR', 'H', 'H_ERR', 'K',
#        'K_ERR', 'GAIAEDR3_PARALLAX', 'GAIAEDR3_PARALLAX_ERROR',
#        'GAIAEDR3_PHOT_G_MEAN_MAG', 'GAIAEDR3_PHOT_BP_MEAN_MAG',
#        'GAIAEDR3_PHOT_RP_MEAN_MAG', 'TEFF', 'TEFF_ERR', 'LOGG', 'LOGG_ERR',
#        'M_H', 'M_H_ERR', 'ALPHA_M', 'ALPHA_M_ERR', 'W1mag', 'W2mag', 'W3mag',
#        'W4mag', 'Jmag', 'Hmag', 'Kmag', 'e_W1mag', 'e_W2mag', 'qph_w1',
#        'qph_w2', 'Qfl_J', 'Qfl_H', 'Qfl_K', 'snr_bp', 'snr_bp10', 'snr_bp55',
#        'snr_rp', 'snr_rp10', 'snr_rp55'],
#       dtype='object')

# %%
oc_grouped = df_oc.groupby('CLUSTER')
oc_grouped = oc_grouped.filter(lambda x: len(x)>21)

cluster_names = oc_grouped['CLUSTER'].unique()
print(len(cluster_names))
# Out:
# 4

# %%
moh_range = [-2.5, 0.5]
aom_range = [-0.15, 0.45]


# aom_moh_diag = plt.imread("../fig/alpha_dia_bkg.png")

fig, axs = plt.subplots(len(cluster_names),2, figsize=(8, 2.5*len(cluster_names)), sharey=True, sharex=True)

for i, (gn,cluster) in enumerate(oc_grouped.groupby('CLUSTER')):

    ax1, ax2 = axs[i,:]
    ax1.scatter(cluster['moh_cross'], cluster['aom_cross'],
                s=8, c='tomato', marker='^')
    ax1.set_xlim(moh_range)
    ax1.set_ylim(aom_range)
    ax1.hist2d(rdf['M_H'], rdf['ALPHA_M'], bins=100, alpha=0.3,
           cmap='binary', norm=colors.LogNorm())
    ax1.text(0.1, 0.2, cluster_names[i], 
            transform=ax1.transAxes, zorder=3)
    ax1.text(0.4, 0.9, 'Gaia XP',
            transform=ax1.transAxes, zorder=3)
    ax1.set_xlabel('[M/H]'); ax1.set_ylabel(r'[$\alpha$/M]');
    
    ax2.scatter(cluster['M_H'], cluster['ALPHA_M'], 
                s=8, c='royalblue', marker='o')
    ax2.set_xlim(moh_range)
    ax2.set_ylim(aom_range)
    ax2.hist2d(rdf['M_H'], rdf['ALPHA_M'], bins=100, alpha=0.3,
           cmap='binary', norm=colors.LogNorm())
    ax2.text(0.1, 0.2, cluster_names[i],
            transform=ax2.transAxes, zorder=3)
    ax2.text(0.4, 0.9, 'APOGEE',
            transform=ax2.transAxes, zorder=3)
    ax2.set_xlabel('[M/H]'); 
    # ax2.set_ylabel(r'[$\alpha$/M]');

# plt.tight_layout()
fig.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.99, wspace=0, hspace=0)
fig.savefig("../fig/oc_valid.pdf")

# %%
df_oc_lite = df_oc[['source_id', 'tmass_id', 'moh_cross', 'aom_cross', 'Cluster',
                    'e_moh_cross', 'e_aom_cross', 'M_H', 'ALPHA_M', 'FE_H', 'FE_H_ERR'
                    ]]

# %%
df_oc_lite['Cluster'].unique()
# Out:
# array(['ASCC 11', 'ASCC 116', 'ASCC 16', 'Briceno 1', 'ASCC 19',
#        'ASCC 21', 'Berkeley 17', 'Berkeley 43', 'Berkeley 53',
#        'Berkeley 85', 'Dolidze 41', 'BH 131', 'BH 211', 'Collinder 220',
#        'Collinder 69', 'Collinder 95', 'ESO 211 03', 'ESO 518 03',
#        'FSR 0306', 'FSR 0667', 'FSR 0687', 'IC 348', 'King 15',
#        'Koposov 62', 'Melotte 20', 'Melotte 22', 'Melotte 71', 'NGC 1245',
#        'NGC 136', 'NGC 1664', 'NGC 1798', 'NGC 1817', 'NGC 188',
#        'NGC 1912', 'NGC 2204', 'NGC 2232', 'NGC 2324', 'NGC 2353',
#        'NGC 2420', 'NGC 2447', 'NGC 2632', 'NGC 2682', 'NGC 4337',
#        'NGC 6705', 'NGC 6811', 'NGC 6819', 'NGC 6866', 'NGC 7062',
#        'NGC 752', 'NGC 7789', 'Platais 4', 'Ruprecht 18', 'Ruprecht 82',
#        'Ruprecht 85', 'SAI 116', 'VVV CL006', 'SAI 16', 'Teutsch 5',
#        'Trumpler 5', 'Trumpler 20', 'Trumpler 26'], dtype=object)

# %%
df_oc_gc_lite = pd.concat([df_gc_lite, df_oc_lite])

print(df_oc_gc_lite.columns, df_oc_gc_lite.shape)
# Out:
# Index(['source_id', 'tmass_id', 'Cluster', 'moh_cross', 'aom_cross',
#        'e_moh_cross', 'e_aom_cross', 'M_H', 'ALPHA_M', 'FE_H', 'FE_H_ERR'],
#       dtype='object') (359, 11)

# %%
moh_kvxp, aom_kvxp = [], []
moh_ap, aom_ap = [], []
e_moh_kvxp, e_aom_kvxp = [], []
e_moh_ap, e_aom_ap = [], []
feh_c, e_feh_c = [], []
Cluster = []
num_member = []


for i, (gn,cluster) in enumerate(df_oc_gc_lite.groupby('Cluster')):
    
    moh_kvxp.append(cluster['moh_cross'].median())
    aom_kvxp.append(cluster['aom_cross'].median())
    moh_ap.append(cluster['M_H'].median())
    aom_ap.append(cluster['ALPHA_M'].median())
    
    e_moh_kvxp.append(cluster['moh_cross'].std())
    e_aom_kvxp.append(cluster['moh_cross'].std())
    e_moh_ap.append(cluster['M_H'].std())
    e_aom_ap.append(cluster['ALPHA_M'].std())
    
    feh_c.append(cluster['FE_H'].median())
    e_feh_c.append(cluster['FE_H'].std())
    Cluster.append(cluster['Cluster'].unique()[0])
    num_member.append(len(cluster))
    
df_cluster = pd.DataFrame(
    data=zip(Cluster, moh_kvxp, aom_kvxp, moh_ap, aom_ap, 
             e_moh_kvxp, e_aom_kvxp, e_moh_ap, e_aom_ap, feh_c, e_feh_c, num_member),
    columns=['Cluster', 'moh_kvxp', 'aom_kvxp', 'moh_ap', 'aom_ap',
             'e_moh_kvxp', 'e_aom_kvxp', 'e_moh_ap', 'e_aom_ap', 'feh_c', 'e_feh_c', 'num_member']
)   

df_cluster = df_cluster.sort_values(by=['feh_c'])

# %%
fig, axs = plt.subplots(1,2, figsize=(8.5, 4), sharey=True)

ax1, ax2 = axs.ravel()
color_palatte = ["#0e2f56", "#118df0", "#ff304f"]

df_lst = [df_cluster, df_cluster_5]

for i,ax in enumerate(axs.ravel()):

    ax.errorbar(df_lst[i]['feh_c'], df_lst[i]['moh_kvxp']-df_lst[i]['feh_c'],
                xerr=df_lst[i]['e_feh_c'], yerr=df_lst[i]['e_moh_kvxp'], 
                ls="None", zorder=3, color=color_palatte[1])

    ax.errorbar(df_lst[i]['feh_c'],  df_lst[i]['moh_ap']-df_lst[i]['feh_c'],
                xerr=df_lst[i]['e_feh_c'], yerr=df_lst[i]['e_moh_ap'], 
                ls="None", zorder=3, color=color_palatte[2])

    ax.scatter(df_lst[i]['feh_c'], df_lst[i]['moh_kvxp']-df_lst[i]['feh_c'],
               s=10*df_lst[i]['num_member'], 
               marker="o", color=color_palatte[1], zorder=4, label="KVXP")
    
    ax.scatter(df_lst[i]['feh_c'], df_lst[i]['moh_ap']-df_lst[i]['feh_c'],
               s=10*df_lst[i]['num_member'], 
               marker="^", color=color_palatte[2], zorder=4, label="APOGEE")

    ax.axhspan(-0.2, 0.2, -2, 2, color=color_palatte[0], alpha=0.2, lw=0)

    ax.set_xlim([-1.75, 0.45]);
    ax.set_ylim([-0.6, 0.6]);
    ax.set_xlabel("Literature [Fe/H]");
    
    
    if i==0:
        ax.set_ylabel("KVXP [M/H] - Literature [Fe/H]")
        ax.text(-1.6, 0.35, "Open / Globular Clusters \n(All Sample)");
    else:
        ax.legend(loc=4, frameon=False)
        ax.text(-1.6, 0.35, "Open / Globular Clusters \n(Members > 5)");

plt.tight_layout()
fig.subplots_adjust(left=0.1, bottom=0.15, right=0.99, top=0.95, wspace=0, hspace=0)
fig.savefig("../fig/cluster_compare.pdf")

# %%
fig, ax = plt.subplots(1,1, figsize=(8.5, 5))

color_palatte = ["#0e2f56", "#118df0", "#ff304f"]


ax.errorbar(df_cluster_5['feh_c'], df_cluster_5['moh_kvxp']-df_cluster_5['feh_c'],
            xerr=df_cluster_5['e_feh_c'], yerr=df_cluster_5['e_moh_kvxp'], 
            ls="None", zorder=3, color=color_palatte[1])

ax.errorbar(df_cluster_5['feh_c'],  df_cluster_5['moh_ap']-df_cluster_5['feh_c'],
            xerr=df_cluster_5['e_feh_c'], yerr=df_cluster_5['e_moh_ap'], 
            ls="None", zorder=3, color=color_palatte[2])

ax.scatter(df_cluster_5['feh_c'], df_cluster_5['moh_kvxp']-df_cluster_5['feh_c'],
           s=10*df_cluster_5['num_member'], 
           marker="o", color=color_palatte[1], zorder=4, label="KVXP")
ax.scatter(df_cluster_5['feh_c'], df_cluster_5['moh_ap']-df_cluster_5['feh_c'],
           s=10*df_cluster_5['num_member'], 
           marker="^", color=color_palatte[2], zorder=4, label="APOGEE")

ax.axhspan(-0.1, 0.1, -2, 2, color=color_palatte[0], alpha=0.2, lw=0)

ax.set_xlim([-1.75, 0.45]);
ax.set_ylim([-0.5, 0.5]);
ax.set_xlabel("Literature [Fe/H]");
ax.set_ylabel("KVXP [M/H] - Literature [Fe/H]");
ax.legend(loc=4, frameon=False)
ax.text(-1.6, 0.4, "Open / Globular Clusters");

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_cluster = df_cluster.dropna()

# %%
# df_cluster.style.format(
#     subset=['moh_kvxp', 'aom_kvxp', 'moh_ap', 'aom_ap',
#              'e_moh_kvxp', 'e_aom_kvxp', 'e_moh_ap', 'e_aom_ap', 'feh_c', 'e_feh_c'], precision=2
# ).to_latex(float_format='%.2f')


df_cluster.to_latex(index=False, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [543], in <cell line: 1>()
# ----> 1 df_cluster.style.format(
#       2     subset=['moh_kvxp', 'aom_kvxp', 'moh_ap', 'aom_ap',
#       3              'e_moh_kvxp', 'e_aom_kvxp', 'e_moh_ap', 'e_aom_ap', 'feh_c', 'e_feh_c'], precision=2
#       4 ).to_latex(index=False, float_format='%.2f')
#
# TypeError: to_latex() got an unexpected keyword argument 'index'
